# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0066 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00231, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00231 to 0.00188, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss did not improve from 0.00188
# Epoch 4/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00188
# Epoch 5/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss improved from 0.00188 to 0.00186, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.5485e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00186 to 0.00167, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.1126e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss did not improve from 0.00167
# Epoch 8/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 7.3985e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00167 to 0.00157, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 6.5959e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00157 to 0.00126, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 5.7766e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss did not improve from 0.00126
# Epoch 11/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 5.3283e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00126 to 0.00112, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 5.0680e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00112 to 0.00109, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.5022e-04 - val_loss: 9.8762e-04
#
# Epoch 00013: val_loss improved from 0.00109 to 0.00099, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.3810e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss did not improve from 0.00099
# Epoch 15/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.0364e-04 - val_loss: 9.3234e-04
#
# Epoch 00015: val_loss improved from 0.00099 to 0.00093, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.8178e-04 - val_loss: 9.5498e-04
#
# Epoch 00016: val_loss did not improve from 0.00093
# Epoch 17/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.7414e-04 - val_loss: 9.1080e-04
#
# Epoch 00017: val_loss improved from 0.00093 to 0.00091, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.5458e-04 - val_loss: 8.7572e-04
#
# Epoch 00018: val_loss improved from 0.00091 to 0.00088, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.4242e-04 - val_loss: 8.9142e-04
#
# Epoch 00019: val_loss did not improve from 0.00088
# Epoch 20/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.4437e-04 - val_loss: 9.0017e-04
#
# Epoch 00020: val_loss did not improve from 0.00088
# Epoch 21/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.2552e-04 - val_loss: 9.2359e-04
#
# Epoch 00021: val_loss did not improve from 0.00088
# Epoch 22/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.1410e-04 - val_loss: 8.5380e-04
#
# Epoch 00022: val_loss improved from 0.00088 to 0.00085, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.9879e-04 - val_loss: 8.0545e-04
#
# Epoch 00023: val_loss improved from 0.00085 to 0.00081, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.9542e-04 - val_loss: 8.2702e-04
#
# Epoch 00024: val_loss did not improve from 0.00081
# Epoch 25/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.8222e-04 - val_loss: 7.9016e-04
#
# Epoch 00025: val_loss improved from 0.00081 to 0.00079, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.7446e-04 - val_loss: 8.0972e-04
#
# Epoch 00026: val_loss did not improve from 0.00079
# Epoch 27/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.7570e-04 - val_loss: 7.9606e-04
#
# Epoch 00027: val_loss did not improve from 0.00079
# Epoch 28/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.6269e-04 - val_loss: 8.2826e-04
#
# Epoch 00028: val_loss did not improve from 0.00079
# Epoch 29/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.5383e-04 - val_loss: 7.6111e-04
#
# Epoch 00029: val_loss improved from 0.00079 to 0.00076, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.5897e-04 - val_loss: 7.7173e-04
#
# Epoch 00030: val_loss did not improve from 0.00076
# Epoch 31/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.5127e-04 - val_loss: 7.5525e-04
#
# Epoch 00031: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.4635e-04 - val_loss: 7.4224e-04
#
# Epoch 00032: val_loss improved from 0.00076 to 0.00074, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.4106e-04 - val_loss: 7.6847e-04
#
# Epoch 00033: val_loss did not improve from 0.00074
# Epoch 34/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.3288e-04 - val_loss: 7.5166e-04
#
# Epoch 00034: val_loss did not improve from 0.00074
# Epoch 35/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.2563e-04 - val_loss: 7.6548e-04
#
# Epoch 00035: val_loss did not improve from 0.00074
# Epoch 36/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.2006e-04 - val_loss: 7.4963e-04
#
# Epoch 00036: val_loss did not improve from 0.00074
# Epoch 37/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.2019e-04 - val_loss: 7.5955e-04
#
# Epoch 00037: val_loss did not improve from 0.00074
# Epoch 38/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.1685e-04 - val_loss: 7.5368e-04
#
# Epoch 00038: val_loss did not improve from 0.00074
# Epoch 39/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.1421e-04 - val_loss: 7.6267e-04
#
# Epoch 00039: val_loss did not improve from 0.00074
# Epoch 40/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.0724e-04 - val_loss: 7.5732e-04
#
# Epoch 00040: val_loss did not improve from 0.00074
# Epoch 41/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0783e-04 - val_loss: 7.6312e-04
#
# Epoch 00041: val_loss did not improve from 0.00074
# Epoch 42/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0532e-04 - val_loss: 8.0370e-04
#
# Epoch 00042: val_loss did not improve from 0.00074
# Epoch 43/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.0444e-04 - val_loss: 7.5751e-04
#
# Epoch 00043: val_loss did not improve from 0.00074
# Epoch 44/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9747e-04 - val_loss: 7.5671e-04
#
# Epoch 00044: val_loss did not improve from 0.00074
# Epoch 45/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9602e-04 - val_loss: 7.5591e-04
#
# Epoch 00045: val_loss did not improve from 0.00074
# Epoch 46/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9547e-04 - val_loss: 7.4264e-04
#
# Epoch 00046: val_loss did not improve from 0.00074
# Epoch 47/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.0000e-04 - val_loss: 7.4436e-04
#
# Epoch 00047: val_loss did not improve from 0.00074
# Epoch 48/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9129e-04 - val_loss: 7.5557e-04
#
# Epoch 00048: val_loss did not improve from 0.00074
# Epoch 49/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8923e-04 - val_loss: 7.3747e-04
#
# Epoch 00049: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7664e-04 - val_loss: 7.2849e-04
#
# Epoch 00050: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.8585e-04 - val_loss: 7.5102e-04
#
# Epoch 00051: val_loss did not improve from 0.00073
# Epoch 52/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7933e-04 - val_loss: 7.3496e-04
#
# Epoch 00052: val_loss did not improve from 0.00073
# Epoch 53/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7685e-04 - val_loss: 7.7869e-04
#
# Epoch 00053: val_loss did not improve from 0.00073
# Epoch 54/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7576e-04 - val_loss: 7.9464e-04
#
# Epoch 00054: val_loss did not improve from 0.00073
# Epoch 55/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6972e-04 - val_loss: 7.2684e-04
#
# Epoch 00055: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 56/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7981e-04 - val_loss: 7.4419e-04
#
# Epoch 00056: val_loss did not improve from 0.00073
# Epoch 57/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7354e-04 - val_loss: 7.5928e-04
#
# Epoch 00057: val_loss did not improve from 0.00073
# Epoch 58/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6258e-04 - val_loss: 7.4618e-04
#
# Epoch 00058: val_loss did not improve from 0.00073
# Epoch 59/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6357e-04 - val_loss: 7.4729e-04
#
# Epoch 00059: val_loss did not improve from 0.00073
# Epoch 60/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5986e-04 - val_loss: 7.4604e-04
#
# Epoch 00060: val_loss did not improve from 0.00073
# Epoch 61/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6348e-04 - val_loss: 7.7498e-04
#
# Epoch 00061: val_loss did not improve from 0.00073
# Epoch 62/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6809e-04 - val_loss: 7.8683e-04
#
# Epoch 00062: val_loss did not improve from 0.00073
# Epoch 63/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6129e-04 - val_loss: 7.4495e-04
#
# Epoch 00063: val_loss did not improve from 0.00073
# Epoch 64/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6582e-04 - val_loss: 7.7007e-04
#
# Epoch 00064: val_loss did not improve from 0.00073
# Epoch 65/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5131e-04 - val_loss: 7.5510e-04
#
# Epoch 00065: val_loss did not improve from 0.00073
# Epoch 66/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5933e-04 - val_loss: 7.3393e-04
#
# Epoch 00066: val_loss did not improve from 0.00073
# Epoch 67/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5310e-04 - val_loss: 7.3313e-04
#
# Epoch 00067: val_loss did not improve from 0.00073
# Epoch 68/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5698e-04 - val_loss: 7.4082e-04
#
# Epoch 00068: val_loss did not improve from 0.00073
# Epoch 69/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6199e-04 - val_loss: 7.2374e-04
#
# Epoch 00069: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 70/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5134e-04 - val_loss: 7.8580e-04
#
# Epoch 00070: val_loss did not improve from 0.00072
# Epoch 71/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4691e-04 - val_loss: 7.3222e-04
#
# Epoch 00071: val_loss did not improve from 0.00072
# Epoch 72/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4578e-04 - val_loss: 7.5052e-04
#
# Epoch 00072: val_loss did not improve from 0.00072
# Epoch 73/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4529e-04 - val_loss: 7.2664e-04
#
# Epoch 00073: val_loss did not improve from 0.00072
# Epoch 74/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4055e-04 - val_loss: 7.2670e-04
#
# Epoch 00074: val_loss did not improve from 0.00072
# Epoch 75/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4148e-04 - val_loss: 7.3552e-04
#
# Epoch 00075: val_loss did not improve from 0.00072
# Epoch 76/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3823e-04 - val_loss: 7.6301e-04
#
# Epoch 00076: val_loss did not improve from 0.00072
# Epoch 77/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3863e-04 - val_loss: 7.2271e-04
#
# Epoch 00077: val_loss improved from 0.00072 to 0.00072, saving model to best_weights.h5
# Epoch 78/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3442e-04 - val_loss: 7.4748e-04
#
# Epoch 00078: val_loss did not improve from 0.00072
# Epoch 79/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3849e-04 - val_loss: 7.6171e-04
#
# Epoch 00079: val_loss did not improve from 0.00072
# Epoch 80/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3780e-04 - val_loss: 7.6515e-04
#
# Epoch 00080: val_loss did not improve from 0.00072
# Epoch 81/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4003e-04 - val_loss: 7.2733e-04
#
# Epoch 00081: val_loss did not improve from 0.00072
# Epoch 82/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3586e-04 - val_loss: 7.5326e-04
#
# Epoch 00082: val_loss did not improve from 0.00072
# Epoch 83/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3409e-04 - val_loss: 7.3937e-04
#
# Epoch 00083: val_loss did not improve from 0.00072
# Epoch 84/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3015e-04 - val_loss: 7.4344e-04
#
# Epoch 00084: val_loss did not improve from 0.00072
# Epoch 85/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3028e-04 - val_loss: 7.5168e-04
#
# Epoch 00085: val_loss did not improve from 0.00072
# Epoch 86/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2671e-04 - val_loss: 7.7829e-04
#
# Epoch 00086: val_loss did not improve from 0.00072
# Epoch 87/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2646e-04 - val_loss: 7.2751e-04
#
# Epoch 00087: val_loss did not improve from 0.00072
# Epoch 88/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2926e-04 - val_loss: 6.9705e-04
#
# Epoch 00088: val_loss improved from 0.00072 to 0.00070, saving model to best_weights.h5
# Epoch 89/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2918e-04 - val_loss: 7.5512e-04
#
# Epoch 00089: val_loss did not improve from 0.00070
# Epoch 90/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2453e-04 - val_loss: 7.3378e-04
#
# Epoch 00090: val_loss did not improve from 0.00070
# Epoch 91/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2292e-04 - val_loss: 7.4901e-04
#
# Epoch 00091: val_loss did not improve from 0.00070
# Epoch 92/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2836e-04 - val_loss: 7.4258e-04
#
# Epoch 00092: val_loss did not improve from 0.00070
# Epoch 93/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2204e-04 - val_loss: 7.3691e-04
#
# Epoch 00093: val_loss did not improve from 0.00070
# Epoch 94/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2355e-04 - val_loss: 7.2373e-04
#
# Epoch 00094: val_loss did not improve from 0.00070
# Epoch 95/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1851e-04 - val_loss: 7.4346e-04
#
# Epoch 00095: val_loss did not improve from 0.00070
# Epoch 96/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1691e-04 - val_loss: 7.6253e-04
#
# Epoch 00096: val_loss did not improve from 0.00070
# Epoch 97/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1996e-04 - val_loss: 7.2854e-04
#
# Epoch 00097: val_loss did not improve from 0.00070
# Epoch 98/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2162e-04 - val_loss: 7.3426e-04
#
# Epoch 00098: val_loss did not improve from 0.00070
# Epoch 99/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1529e-04 - val_loss: 7.3413e-04
#
# Epoch 00099: val_loss did not improve from 0.00070
# Epoch 100/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1867e-04 - val_loss: 7.5751e-04
#
# Epoch 00100: val_loss did not improve from 0.00070
# Epoch 101/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1949e-04 - val_loss: 7.4232e-04
#
# Epoch 00101: val_loss did not improve from 0.00070
# Epoch 102/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1516e-04 - val_loss: 7.7046e-04
#
# Epoch 00102: val_loss did not improve from 0.00070
# Epoch 103/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1711e-04 - val_loss: 7.6736e-04
#
# Epoch 00103: val_loss did not improve from 0.00070
# Epoch 104/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1023e-04 - val_loss: 7.2901e-04
#
# Epoch 00104: val_loss did not improve from 0.00070
# Epoch 105/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1210e-04 - val_loss: 7.6209e-04
#
# Epoch 00105: val_loss did not improve from 0.00070
# Epoch 106/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1336e-04 - val_loss: 7.2488e-04
#
# Epoch 00106: val_loss did not improve from 0.00070
# Epoch 107/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1446e-04 - val_loss: 7.1436e-04
#
# Epoch 00107: val_loss did not improve from 0.00070
# Epoch 108/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1511e-04 - val_loss: 7.5473e-04
#
# Epoch 00108: val_loss did not improve from 0.00070
# Epoch 109/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1244e-04 - val_loss: 7.4328e-04
#
# Epoch 00109: val_loss did not improve from 0.00070
# Epoch 110/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0905e-04 - val_loss: 7.1432e-04
#
# Epoch 00110: val_loss did not improve from 0.00070
# Epoch 111/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0584e-04 - val_loss: 7.1629e-04
#
# Epoch 00111: val_loss did not improve from 0.00070
# Epoch 112/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0458e-04 - val_loss: 7.3639e-04
#
# Epoch 00112: val_loss did not improve from 0.00070
# Epoch 113/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0437e-04 - val_loss: 7.5974e-04
#
# Epoch 00113: val_loss did not improve from 0.00070
# Epoch 114/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0586e-04 - val_loss: 7.3613e-04
#
# Epoch 00114: val_loss did not improve from 0.00070
# Epoch 115/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0554e-04 - val_loss: 7.1981e-04
#
# Epoch 00115: val_loss did not improve from 0.00070
# Epoch 116/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1357e-04 - val_loss: 7.1403e-04
#
# Epoch 00116: val_loss did not improve from 0.00070
# Epoch 117/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0692e-04 - val_loss: 7.7782e-04
#
# Epoch 00117: val_loss did not improve from 0.00070
# Epoch 118/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0778e-04 - val_loss: 7.1127e-04
#
# Epoch 00118: val_loss did not improve from 0.00070
# Epoch 119/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0107e-04 - val_loss: 7.1739e-04
#
# Epoch 00119: val_loss did not improve from 0.00070
# Epoch 120/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0433e-04 - val_loss: 7.7303e-04
#
# Epoch 00120: val_loss did not improve from 0.00070
# Epoch 121/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0056e-04 - val_loss: 7.3474e-04
#
# Epoch 00121: val_loss did not improve from 0.00070
# Epoch 122/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0053e-04 - val_loss: 7.3378e-04
#
# Epoch 00122: val_loss did not improve from 0.00070
# Epoch 123/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0202e-04 - val_loss: 7.3287e-04
#
# Epoch 00123: val_loss did not improve from 0.00070
# Epoch 124/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0087e-04 - val_loss: 7.4358e-04
#
# Epoch 00124: val_loss did not improve from 0.00070
# Epoch 125/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.6587e-05 - val_loss: 7.6547e-04
#
# Epoch 00125: val_loss did not improve from 0.00070
# Epoch 126/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.7997e-05 - val_loss: 7.2435e-04
#
# Epoch 00126: val_loss did not improve from 0.00070
# Epoch 127/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.7322e-05 - val_loss: 7.2924e-04
#
# Epoch 00127: val_loss did not improve from 0.00070
# Epoch 128/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.5750e-05 - val_loss: 7.4516e-04
#
# Epoch 00128: val_loss did not improve from 0.00070
# Epoch 129/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.8124e-05 - val_loss: 7.6858e-04
#
# Epoch 00129: val_loss did not improve from 0.00070
# Epoch 130/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.7074e-05 - val_loss: 7.3440e-04
#
# Epoch 00130: val_loss did not improve from 0.00070
# Epoch 131/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.6292e-05 - val_loss: 7.4902e-04
#
# Epoch 00131: val_loss did not improve from 0.00070
# Epoch 132/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.3269e-05 - val_loss: 7.3817e-04
#
# Epoch 00132: val_loss did not improve from 0.00070
# Epoch 133/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.4764e-05 - val_loss: 7.3110e-04
#
# Epoch 00133: val_loss did not improve from 0.00070
# Epoch 134/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.1963e-05 - val_loss: 7.3790e-04
#
# Epoch 00134: val_loss did not improve from 0.00070
# Epoch 135/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.4873e-05 - val_loss: 7.6933e-04
#
# Epoch 00135: val_loss did not improve from 0.00070
# Epoch 136/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.9158e-05 - val_loss: 7.6796e-04
# Epoch 00136: val_loss did not improve from 0.00070
# Epoch 137/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.5209e-05 - val_loss: 7.6680e-04
#
# Epoch 00137: val_loss did not improve from 0.00070
# Epoch 138/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.2466e-05 - val_loss: 7.2014e-04
#
# Epoch 00138: val_loss did not improve from 0.00070
# Epoch 139/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.1976e-05 - val_loss: 7.3659e-04
#
# Epoch 00139: val_loss did not improve from 0.00070
# Epoch 140/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.3660e-05 - val_loss: 7.4499e-04
#
# Epoch 00140: val_loss did not improve from 0.00070
# Epoch 141/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.4603e-05 - val_loss: 7.6662e-04
#
# Epoch 00141: val_loss did not improve from 0.00070
# Epoch 142/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.3029e-05 - val_loss: 7.5585e-04
#
# Epoch 00142: val_loss did not improve from 0.00070
# Epoch 143/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.0984e-05 - val_loss: 7.3858e-04
#
# Epoch 00143: val_loss did not improve from 0.00070
# Epoch 144/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.9310e-05 - val_loss: 7.6269e-04
#
# Epoch 00144: val_loss did not improve from 0.00070
# Epoch 145/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.9529e-05 - val_loss: 7.3934e-04
#
# Epoch 00145: val_loss did not improve from 0.00070
# Epoch 146/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.2357e-05 - val_loss: 7.3978e-04
#
# Epoch 00146: val_loss did not improve from 0.00070
# Epoch 147/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.9839e-05 - val_loss: 7.4789e-04
#
# Epoch 00147: val_loss did not improve from 0.00070
# Epoch 148/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.0449e-05 - val_loss: 7.4653e-04
#
# Epoch 00148: val_loss did not improve from 0.00070
# Epoch 149/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.8586e-05 - val_loss: 7.4530e-04
#
# Epoch 00149: val_loss did not improve from 0.00070
# Epoch 150/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.6917e-05 - val_loss: 7.4203e-04
#
# Epoch 00150: val_loss did not improve from 0.00070

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
