# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0069 - val_loss: 0.0022
#
# Epoch 00001: val_loss improved from inf to 0.00215, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0018 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00215 to 0.00195, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 0.0014 - val_loss: 0.0020
#
# Epoch 00003: val_loss improved from 0.00195 to 0.00195, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0013 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00195 to 0.00184, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss did not improve from 0.00184
# Epoch 6/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00184 to 0.00179, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2043e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00179 to 0.00172, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 7.9872e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00172 to 0.00145, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 6.8312e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00145 to 0.00138, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 6.2236e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00138 to 0.00131, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 5.5210e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00131 to 0.00119, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 5.0907e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00119 to 0.00111, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.8133e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00111 to 0.00106, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.6219e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00106 to 0.00103, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.1805e-04 - val_loss: 0.0010
#
# Epoch 00015: val_loss improved from 0.00103 to 0.00100, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.0203e-04 - val_loss: 9.4270e-04
#
# Epoch 00016: val_loss improved from 0.00100 to 0.00094, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.8135e-04 - val_loss: 9.6800e-04
#
# Epoch 00017: val_loss did not improve from 0.00094
# Epoch 18/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.5912e-04 - val_loss: 8.9368e-04
#
# Epoch 00018: val_loss improved from 0.00094 to 0.00089, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 3.4658e-04 - val_loss: 8.8985e-04
#
# Epoch 00019: val_loss improved from 0.00089 to 0.00089, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.3939e-04 - val_loss: 8.7661e-04
#
# Epoch 00020: val_loss improved from 0.00089 to 0.00088, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.3348e-04 - val_loss: 8.5658e-04
#
# Epoch 00021: val_loss improved from 0.00088 to 0.00086, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.2233e-04 - val_loss: 8.4096e-04
#
# Epoch 00022: val_loss improved from 0.00086 to 0.00084, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.0260e-04 - val_loss: 8.4468e-04
#
# Epoch 00023: val_loss did not improve from 0.00084
# Epoch 24/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.9783e-04 - val_loss: 8.5433e-04
#
# Epoch 00024: val_loss did not improve from 0.00084
# Epoch 25/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.8728e-04 - val_loss: 8.5974e-04
#
# Epoch 00025: val_loss did not improve from 0.00084
# Epoch 26/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.8030e-04 - val_loss: 8.5143e-04
#
# Epoch 00026: val_loss did not improve from 0.00084
# Epoch 27/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.8233e-04 - val_loss: 8.2512e-04
#
# Epoch 00027: val_loss improved from 0.00084 to 0.00083, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.7033e-04 - val_loss: 8.0807e-04
#
# Epoch 00028: val_loss improved from 0.00083 to 0.00081, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.6507e-04 - val_loss: 8.5237e-04
#
# Epoch 00029: val_loss did not improve from 0.00081
# Epoch 30/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.5383e-04 - val_loss: 8.3612e-04
#
# Epoch 00030: val_loss did not improve from 0.00081
# Epoch 31/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4705e-04 - val_loss: 7.9820e-04
#
# Epoch 00031: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.4106e-04 - val_loss: 7.8792e-04
#
# Epoch 00032: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.4230e-04 - val_loss: 8.3527e-04
#
# Epoch 00033: val_loss did not improve from 0.00079
# Epoch 34/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4043e-04 - val_loss: 8.0504e-04
#
# Epoch 00034: val_loss did not improve from 0.00079
# Epoch 35/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.3265e-04 - val_loss: 7.9134e-04
#
# Epoch 00035: val_loss did not improve from 0.00079
# Epoch 36/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.3209e-04 - val_loss: 7.6610e-04
#
# Epoch 00036: val_loss improved from 0.00079 to 0.00077, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2333e-04 - val_loss: 7.8952e-04
#
# Epoch 00037: val_loss did not improve from 0.00077
# Epoch 38/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2349e-04 - val_loss: 8.0016e-04
#
# Epoch 00038: val_loss did not improve from 0.00077
# Epoch 39/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2201e-04 - val_loss: 7.8602e-04
#
# Epoch 00039: val_loss did not improve from 0.00077
# Epoch 40/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0803e-04 - val_loss: 7.8614e-04
#
# Epoch 00040: val_loss did not improve from 0.00077
# Epoch 41/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1033e-04 - val_loss: 7.6500e-04
#
# Epoch 00041: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 42/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0825e-04 - val_loss: 8.0596e-04
#
# Epoch 00042: val_loss did not improve from 0.00076
# Epoch 43/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0314e-04 - val_loss: 7.7098e-04
#
# Epoch 00043: val_loss did not improve from 0.00076
# Epoch 44/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0132e-04 - val_loss: 7.6822e-04
#
# Epoch 00044: val_loss did not improve from 0.00076
# Epoch 45/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9857e-04 - val_loss: 8.0032e-04
#
# Epoch 00045: val_loss did not improve from 0.00076
# Epoch 46/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9320e-04 - val_loss: 7.7238e-04
#
# Epoch 00046: val_loss did not improve from 0.00076
# Epoch 47/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8967e-04 - val_loss: 7.7242e-04
#
# Epoch 00047: val_loss did not improve from 0.00076
# Epoch 48/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0314e-04 - val_loss: 7.9028e-04
#
# Epoch 00048: val_loss did not improve from 0.00076
# Epoch 49/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8843e-04 - val_loss: 8.1174e-04
#
# Epoch 00049: val_loss did not improve from 0.00076
# Epoch 50/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8702e-04 - val_loss: 8.6294e-04
#
# Epoch 00050: val_loss did not improve from 0.00076
# Epoch 51/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.9280e-04 - val_loss: 7.7477e-04
#
# Epoch 00051: val_loss did not improve from 0.00076
# Epoch 52/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.8160e-04 - val_loss: 7.4192e-04
#
# Epoch 00052: val_loss improved from 0.00076 to 0.00074, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8148e-04 - val_loss: 7.7019e-04
#
# Epoch 00053: val_loss did not improve from 0.00074
# Epoch 54/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8570e-04 - val_loss: 7.5386e-04
#
# Epoch 00054: val_loss did not improve from 0.00074
# Epoch 55/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7170e-04 - val_loss: 7.8439e-04
#
# Epoch 00055: val_loss did not improve from 0.00074
# Epoch 56/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.7343e-04 - val_loss: 7.9734e-04
#
# Epoch 00056: val_loss did not improve from 0.00074
# Epoch 57/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.6643e-04 - val_loss: 7.7541e-04
#
# Epoch 00057: val_loss did not improve from 0.00074
# Epoch 58/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.6813e-04 - val_loss: 7.7473e-04
#
# Epoch 00058: val_loss did not improve from 0.00074
# Epoch 59/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.6620e-04 - val_loss: 7.4726e-04
#
# Epoch 00059: val_loss did not improve from 0.00074
# Epoch 60/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6626e-04 - val_loss: 7.5865e-04
#
# Epoch 00060: val_loss did not improve from 0.00074
# Epoch 61/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 1.5776e-04 - val_loss: 7.6992e-04
#
# Epoch 00061: val_loss did not improve from 0.00074
# Epoch 62/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.5917e-04 - val_loss: 7.5475e-04
#
# Epoch 00062: val_loss did not improve from 0.00074
# Epoch 63/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5956e-04 - val_loss: 7.7061e-04
#
# Epoch 00063: val_loss did not improve from 0.00074
# Epoch 64/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5975e-04 - val_loss: 7.7307e-04
#
# Epoch 00064: val_loss did not improve from 0.00074
# Epoch 65/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6349e-04 - val_loss: 7.8110e-04
#
# Epoch 00065: val_loss did not improve from 0.00074
# Epoch 66/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6241e-04 - val_loss: 7.5238e-04
#
# Epoch 00066: val_loss did not improve from 0.00074
# Epoch 67/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5724e-04 - val_loss: 7.5365e-04
#
# Epoch 00067: val_loss did not improve from 0.00074
# Epoch 68/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5426e-04 - val_loss: 7.9200e-04
#
# Epoch 00068: val_loss did not improve from 0.00074
# Epoch 69/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5325e-04 - val_loss: 7.5804e-04
#
# Epoch 00069: val_loss did not improve from 0.00074
# Epoch 70/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4917e-04 - val_loss: 7.6103e-04
#
# Epoch 00070: val_loss did not improve from 0.00074
# Epoch 71/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4982e-04 - val_loss: 7.7641e-04
#
# Epoch 00071: val_loss did not improve from 0.00074
# Epoch 72/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4849e-04 - val_loss: 7.5932e-04
#
# Epoch 00072: val_loss did not improve from 0.00074
# Epoch 73/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4864e-04 - val_loss: 7.5864e-04
#
# Epoch 00073: val_loss did not improve from 0.00074
# Epoch 74/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4766e-04 - val_loss: 7.6777e-04
#
# Epoch 00074: val_loss did not improve from 0.00074
# Epoch 75/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4274e-04 - val_loss: 7.7239e-04
#
# Epoch 00075: val_loss did not improve from 0.00074
# Epoch 76/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4246e-04 - val_loss: 7.6571e-04
#
# Epoch 00076: val_loss did not improve from 0.00074
# Epoch 77/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4164e-04 - val_loss: 8.0312e-04
#
# Epoch 00077: val_loss did not improve from 0.00074
# Epoch 78/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3947e-04 - val_loss: 7.6553e-04
#
# Epoch 00078: val_loss did not improve from 0.00074
# Epoch 79/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4076e-04 - val_loss: 7.4762e-04
#
# Epoch 00079: val_loss did not improve from 0.00074
# Epoch 80/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3974e-04 - val_loss: 7.3774e-04
#
# Epoch 00080: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 81/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3953e-04 - val_loss: 7.7293e-04
#
# Epoch 00081: val_loss did not improve from 0.00074
# Epoch 82/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3356e-04 - val_loss: 7.6102e-04
#
# Epoch 00082: val_loss did not improve from 0.00074
# Epoch 83/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3239e-04 - val_loss: 7.6945e-04
#
# Epoch 00083: val_loss did not improve from 0.00074
# Epoch 84/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2940e-04 - val_loss: 7.3402e-04
#
# Epoch 00084: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 85/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3234e-04 - val_loss: 7.3657e-04
#
# Epoch 00085: val_loss did not improve from 0.00073
# Epoch 86/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3297e-04 - val_loss: 7.6140e-04
#
# Epoch 00086: val_loss did not improve from 0.00073
# Epoch 87/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3356e-04 - val_loss: 7.3466e-04
#
# Epoch 00087: val_loss did not improve from 0.00073
# Epoch 88/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2846e-04 - val_loss: 7.3403e-04
#
# Epoch 00088: val_loss did not improve from 0.00073
# Epoch 89/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2810e-04 - val_loss: 7.9040e-04
#
# Epoch 00089: val_loss did not improve from 0.00073
# Epoch 90/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2817e-04 - val_loss: 7.5366e-04
#
# Epoch 00090: val_loss did not improve from 0.00073
# Epoch 91/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2434e-04 - val_loss: 7.6391e-04
#
# Epoch 00091: val_loss did not improve from 0.00073
# Epoch 92/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2462e-04 - val_loss: 7.4494e-04
#
# Epoch 00092: val_loss did not improve from 0.00073
# Epoch 93/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3151e-04 - val_loss: 7.4340e-04
#
# Epoch 00093: val_loss did not improve from 0.00073
# Epoch 94/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2888e-04 - val_loss: 7.6351e-04
#
# Epoch 00094: val_loss did not improve from 0.00073
# Epoch 95/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2654e-04 - val_loss: 7.8725e-04
#
# Epoch 00095: val_loss did not improve from 0.00073
# Epoch 96/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1865e-04 - val_loss: 7.6781e-04
#
# Epoch 00096: val_loss did not improve from 0.00073
# Epoch 97/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1838e-04 - val_loss: 7.6164e-04
#
# Epoch 00097: val_loss did not improve from 0.00073
# Epoch 98/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1782e-04 - val_loss: 7.3877e-04
#
# Epoch 00098: val_loss did not improve from 0.00073
# Epoch 99/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1876e-04 - val_loss: 7.8548e-04
#
# Epoch 00099: val_loss did not improve from 0.00073
# Epoch 100/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1924e-04 - val_loss: 8.0284e-04
#
# Epoch 00100: val_loss did not improve from 0.00073
# Epoch 101/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1876e-04 - val_loss: 7.7434e-04
#
# Epoch 00101: val_loss did not improve from 0.00073
# Epoch 102/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1261e-04 - val_loss: 7.3555e-04
#
# Epoch 00102: val_loss did not improve from 0.00073
# Epoch 103/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1445e-04 - val_loss: 7.4634e-04
#
# Epoch 00103: val_loss did not improve from 0.00073
# Epoch 104/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1358e-04 - val_loss: 7.8305e-04
#
# Epoch 00104: val_loss did not improve from 0.00073
# Epoch 105/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1542e-04 - val_loss: 7.5401e-04
#
# Epoch 00105: val_loss did not improve from 0.00073
# Epoch 106/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1240e-04 - val_loss: 7.3076e-04
#
# Epoch 00106: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 107/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0927e-04 - val_loss: 7.7887e-04
#
# Epoch 00107: val_loss did not improve from 0.00073
# Epoch 108/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0965e-04 - val_loss: 7.3922e-04
#
# Epoch 00108: val_loss did not improve from 0.00073
# Epoch 109/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0678e-04 - val_loss: 7.3938e-04
#
# Epoch 00109: val_loss did not improve from 0.00073
# Epoch 110/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1074e-04 - val_loss: 7.5539e-04
#
# Epoch 00110: val_loss did not improve from 0.00073
# Epoch 111/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0893e-04 - val_loss: 7.5121e-04
#
# Epoch 00111: val_loss did not improve from 0.00073
# Epoch 112/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0575e-04 - val_loss: 7.6711e-04
#
# Epoch 00112: val_loss did not improve from 0.00073
# Epoch 113/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0550e-04 - val_loss: 7.6005e-04
#
# Epoch 00113: val_loss did not improve from 0.00073
# Epoch 114/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0692e-04 - val_loss: 7.8719e-04
#
# Epoch 00114: val_loss did not improve from 0.00073
# Epoch 115/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1080e-04 - val_loss: 7.7109e-04
#
# Epoch 00115: val_loss did not improve from 0.00073
# Epoch 116/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0605e-04 - val_loss: 7.4895e-04
#
# Epoch 00116: val_loss did not improve from 0.00073
# Epoch 117/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0676e-04 - val_loss: 7.5273e-04
#
# Epoch 00117: val_loss did not improve from 0.00073
# Epoch 118/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0599e-04 - val_loss: 8.0649e-04
#
# Epoch 00118: val_loss did not improve from 0.00073
# Epoch 119/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0691e-04 - val_loss: 7.5654e-04
#
# Epoch 00119: val_loss did not improve from 0.00073
# Epoch 120/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0566e-04 - val_loss: 7.7544e-04
#
# Epoch 00120: val_loss did not improve from 0.00073
# Epoch 121/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0760e-04 - val_loss: 7.6223e-04
#
# Epoch 00121: val_loss did not improve from 0.00073
# Epoch 122/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0448e-04 - val_loss: 7.6803e-04
#
# Epoch 00122: val_loss did not improve from 0.00073
# Epoch 123/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0380e-04 - val_loss: 7.5314e-04
#
# Epoch 00123: val_loss did not improve from 0.00073
# Epoch 124/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0076e-04 - val_loss: 7.6913e-04
#
# Epoch 00124: val_loss did not improve from 0.00073
# Epoch 125/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0181e-04 - val_loss: 7.3301e-04
#
# Epoch 00125: val_loss did not improve from 0.00073
# Epoch 126/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.9889e-05 - val_loss: 7.6349e-04
#
# Epoch 00126: val_loss did not improve from 0.00073
# Epoch 127/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0049e-04 - val_loss: 7.3524e-04
#
# Epoch 00127: val_loss did not improve from 0.00073
# Epoch 128/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.7709e-05 - val_loss: 7.7291e-04
#
# Epoch 00128: val_loss did not improve from 0.00073
# Epoch 129/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.9127e-05 - val_loss: 7.3762e-04
#
# Epoch 00129: val_loss did not improve from 0.00073
# Epoch 130/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.9562e-05 - val_loss: 7.5597e-04
#
# Epoch 00130: val_loss did not improve from 0.00073
# Epoch 131/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.9354e-05 - val_loss: 7.7218e-04
#
# Epoch 00131: val_loss did not improve from 0.00073
# Epoch 132/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.5748e-05 - val_loss: 7.7267e-04
#
# Epoch 00132: val_loss did not improve from 0.00073
# Epoch 133/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.8397e-05 - val_loss: 7.9419e-04
#
# Epoch 00133: val_loss did not improve from 0.00073
# Epoch 134/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.4112e-05 - val_loss: 7.8965e-04
#
# Epoch 00134: val_loss did not improve from 0.00073
# Epoch 135/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.5367e-05 - val_loss: 7.6408e-04
# Epoch 00135: val_loss did not improve from 0.00073
# Epoch 136/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.3659e-05 - val_loss: 7.4838e-04
#
# Epoch 00136: val_loss did not improve from 0.00073
# Epoch 137/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.5060e-05 - val_loss: 7.4971e-04
#
# Epoch 00137: val_loss did not improve from 0.00073
# Epoch 138/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2041e-05 - val_loss: 7.8890e-04
#
# Epoch 00138: val_loss did not improve from 0.00073
# Epoch 139/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2411e-05 - val_loss: 7.4408e-04
#
# Epoch 00139: val_loss did not improve from 0.00073
# Epoch 140/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.6469e-05 - val_loss: 7.9070e-04
#
# Epoch 00140: val_loss did not improve from 0.00073
# Epoch 141/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.4087e-05 - val_loss: 7.8976e-04
#
# Epoch 00141: val_loss did not improve from 0.00073
# Epoch 142/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.1932e-05 - val_loss: 7.7967e-04
#
# Epoch 00142: val_loss did not improve from 0.00073
# Epoch 143/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0875e-05 - val_loss: 7.7203e-04
#
# Epoch 00143: val_loss did not improve from 0.00073
# Epoch 144/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.9400e-05 - val_loss: 7.6290e-04
#
# Epoch 00144: val_loss did not improve from 0.00073
# Epoch 145/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0100e-05 - val_loss: 7.4947e-04
#
# Epoch 00145: val_loss did not improve from 0.00073
# Epoch 146/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.8609e-05 - val_loss: 7.7544e-04
#
# Epoch 00146: val_loss did not improve from 0.00073
# Epoch 147/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.6908e-05 - val_loss: 7.6588e-04
#
# Epoch 00147: val_loss did not improve from 0.00073
# Epoch 148/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.1321e-05 - val_loss: 7.5043e-04
#
# Epoch 00148: val_loss did not improve from 0.00073
# Epoch 149/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.7094e-05 - val_loss: 7.3964e-04
#
# Epoch 00149: val_loss did not improve from 0.00073
# Epoch 150/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.7321e-05 - val_loss: 7.7010e-04
#
# Epoch 00150: val_loss did not improve from 0.00073

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 15s 5ms/step - loss: 0.0038 - val_loss: 0.0018
#
# Epoch 00001: val_loss improved from inf to 0.00180, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss did not improve from 0.00180
# Epoch 3/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00180 to 0.00177, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.3417e-04 - val_loss: 0.0014
#
# Epoch 00004: val_loss improved from 0.00177 to 0.00142, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 6.2055e-04 - val_loss: 0.0012
#
# Epoch 00005: val_loss improved from 0.00142 to 0.00121, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 5.2012e-04 - val_loss: 0.0010
#
# Epoch 00006: val_loss improved from 0.00121 to 0.00101, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 4.5681e-04 - val_loss: 9.5861e-04
#
# Epoch 00007: val_loss improved from 0.00101 to 0.00096, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 4.1725e-04 - val_loss: 8.7260e-04
#
# Epoch 00008: val_loss improved from 0.00096 to 0.00087, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 3.8198e-04 - val_loss: 8.2253e-04
#
# Epoch 00009: val_loss improved from 0.00087 to 0.00082, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 3.5954e-04 - val_loss: 8.3733e-04
#
# Epoch 00010: val_loss did not improve from 0.00082
# Epoch 11/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 3.3816e-04 - val_loss: 7.7356e-04
#
# Epoch 00011: val_loss improved from 0.00082 to 0.00077, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 3.2053e-04 - val_loss: 7.8051e-04
#
# Epoch 00012: val_loss did not improve from 0.00077
# Epoch 13/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.9764e-04 - val_loss: 7.2486e-04
#
# Epoch 00013: val_loss improved from 0.00077 to 0.00072, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.8496e-04 - val_loss: 7.5331e-04
#
# Epoch 00014: val_loss did not improve from 0.00072
# Epoch 15/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 2.8040e-04 - val_loss: 6.9106e-04
#
# Epoch 00015: val_loss improved from 0.00072 to 0.00069, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.6694e-04 - val_loss: 7.0155e-04
#
# Epoch 00016: val_loss did not improve from 0.00069
# Epoch 17/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 2.5933e-04 - val_loss: 7.2912e-04
#
# Epoch 00017: val_loss did not improve from 0.00069
# Epoch 18/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.4989e-04 - val_loss: 7.3047e-04
#
# Epoch 00018: val_loss did not improve from 0.00069
# Epoch 19/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.3476e-04 - val_loss: 6.9995e-04
#
# Epoch 00019: val_loss did not improve from 0.00069
# Epoch 20/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.2913e-04 - val_loss: 6.6895e-04
#
# Epoch 00020: val_loss improved from 0.00069 to 0.00067, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 2.3218e-04 - val_loss: 6.4249e-04
#
# Epoch 00021: val_loss improved from 0.00067 to 0.00064, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.1767e-04 - val_loss: 7.1552e-04
#
# Epoch 00022: val_loss did not improve from 0.00064
# Epoch 23/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.1547e-04 - val_loss: 7.0878e-04
#
# Epoch 00023: val_loss did not improve from 0.00064
# Epoch 24/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 2.1778e-04 - val_loss: 7.3759e-04
#
# Epoch 00024: val_loss did not improve from 0.00064
# Epoch 25/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.0184e-04 - val_loss: 6.5074e-04
#
# Epoch 00025: val_loss did not improve from 0.00064
# Epoch 26/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.0425e-04 - val_loss: 6.2526e-04
#
# Epoch 00026: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 27/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.9422e-04 - val_loss: 6.2206e-04
#
# Epoch 00027: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 28/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.9005e-04 - val_loss: 6.7756e-04
#
# Epoch 00028: val_loss did not improve from 0.00062
# Epoch 29/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.9162e-04 - val_loss: 6.7132e-04
#
# Epoch 00029: val_loss did not improve from 0.00062
# Epoch 30/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.8635e-04 - val_loss: 6.2795e-04
#
# Epoch 00030: val_loss did not improve from 0.00062
# Epoch 31/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.7924e-04 - val_loss: 6.2532e-04
#
# Epoch 00031: val_loss did not improve from 0.00062
# Epoch 32/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.7543e-04 - val_loss: 6.1895e-04
#
# Epoch 00032: val_loss improved from 0.00062 to 0.00062, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.7830e-04 - val_loss: 6.6417e-04
#
# Epoch 00033: val_loss did not improve from 0.00062
# Epoch 34/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.7101e-04 - val_loss: 6.7665e-04
#
# Epoch 00034: val_loss did not improve from 0.00062
# Epoch 35/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.7029e-04 - val_loss: 6.0669e-04
#
# Epoch 00035: val_loss improved from 0.00062 to 0.00061, saving model to best_weights_augment.h5
# Epoch 36/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.6955e-04 - val_loss: 6.4346e-04
#
# Epoch 00036: val_loss did not improve from 0.00061
# Epoch 37/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.6485e-04 - val_loss: 6.0977e-04
#
# Epoch 00037: val_loss did not improve from 0.00061
# Epoch 38/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.6310e-04 - val_loss: 6.2486e-04
#
# Epoch 00038: val_loss did not improve from 0.00061
# Epoch 39/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.5940e-04 - val_loss: 6.2064e-04
#
# Epoch 00039: val_loss did not improve from 0.00061
# Epoch 40/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.5230e-04 - val_loss: 6.2377e-04
#
# Epoch 00040: val_loss did not improve from 0.00061
# Epoch 41/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.5463e-04 - val_loss: 6.2469e-04
#
# Epoch 00041: val_loss did not improve from 0.00061
# Epoch 42/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4703e-04 - val_loss: 6.0078e-04
#
# Epoch 00042: val_loss improved from 0.00061 to 0.00060, saving model to best_weights_augment.h5
# Epoch 43/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.4959e-04 - val_loss: 6.4715e-04
#
# Epoch 00043: val_loss did not improve from 0.00060
# Epoch 44/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4870e-04 - val_loss: 6.2085e-04
#
# Epoch 00044: val_loss did not improve from 0.00060
# Epoch 45/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.4529e-04 - val_loss: 6.2215e-04
#
# Epoch 00045: val_loss did not improve from 0.00060
# Epoch 46/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.4108e-04 - val_loss: 6.1592e-04
#
# Epoch 00046: val_loss did not improve from 0.00060
# Epoch 47/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.4109e-04 - val_loss: 6.2708e-04
#
# Epoch 00047: val_loss did not improve from 0.00060
# Epoch 48/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.3871e-04 - val_loss: 6.4258e-04
#
# Epoch 00048: val_loss did not improve from 0.00060
# Epoch 49/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.3742e-04 - val_loss: 6.3175e-04
#
# Epoch 00049: val_loss did not improve from 0.00060
# Epoch 50/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.3235e-04 - val_loss: 5.9185e-04
#
# Epoch 00050: val_loss improved from 0.00060 to 0.00059, saving model to best_weights_augment.h5
# Epoch 51/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.3662e-04 - val_loss: 6.1208e-04
#
# Epoch 00051: val_loss did not improve from 0.00059
# Epoch 52/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3607e-04 - val_loss: 6.0952e-04
#
# Epoch 00052: val_loss did not improve from 0.00059
# Epoch 53/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3306e-04 - val_loss: 6.1189e-04
#
# Epoch 00053: val_loss did not improve from 0.00059
# Epoch 54/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.2647e-04 - val_loss: 6.4298e-04
#
# Epoch 00054: val_loss did not improve from 0.00059
# Epoch 55/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.2520e-04 - val_loss: 6.6731e-04
#
# Epoch 00055: val_loss did not improve from 0.00059
# Epoch 56/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.2457e-04 - val_loss: 5.9750e-04
#
# Epoch 00056: val_loss did not improve from 0.00059
# Epoch 57/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.2198e-04 - val_loss: 6.0564e-04
#
# Epoch 00057: val_loss did not improve from 0.00059
# Epoch 58/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.2175e-04 - val_loss: 6.2742e-04
#
# Epoch 00058: val_loss did not improve from 0.00059
# Epoch 59/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.2197e-04 - val_loss: 6.0404e-04
#
# Epoch 00059: val_loss did not improve from 0.00059
# Epoch 60/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.2033e-04 - val_loss: 6.2390e-04
#
# Epoch 00060: val_loss did not improve from 0.00059
# Epoch 61/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.1737e-04 - val_loss: 6.2592e-04
#
# Epoch 00061: val_loss did not improve from 0.00059
# Epoch 62/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.1439e-04 - val_loss: 6.1612e-04
#
# Epoch 00062: val_loss did not improve from 0.00059
# Epoch 63/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.1442e-04 - val_loss: 6.4522e-04
#
# Epoch 00063: val_loss did not improve from 0.00059
# Epoch 64/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.1360e-04 - val_loss: 6.2570e-04
#
# Epoch 00064: val_loss did not improve from 0.00059
# Epoch 65/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.1312e-04 - val_loss: 6.4854e-04
#
# Epoch 00065: val_loss did not improve from 0.00059
# Epoch 66/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.1437e-04 - val_loss: 6.4964e-04
#
# Epoch 00066: val_loss did not improve from 0.00059
# Epoch 67/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.1289e-04 - val_loss: 6.1215e-04
#
# Epoch 00067: val_loss did not improve from 0.00059
# Epoch 68/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.1158e-04 - val_loss: 6.6747e-04
#
# Epoch 00068: val_loss did not improve from 0.00059
# Epoch 69/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0848e-04 - val_loss: 6.2158e-04
#
# Epoch 00069: val_loss did not improve from 0.00059
# Epoch 70/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0839e-04 - val_loss: 6.3211e-04
#
# Epoch 00070: val_loss did not improve from 0.00059
# Epoch 71/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0857e-04 - val_loss: 6.3710e-04
#
# Epoch 00071: val_loss did not improve from 0.00059
# Epoch 72/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0935e-04 - val_loss: 6.2583e-04
#
# Epoch 00072: val_loss did not improve from 0.00059
# Epoch 73/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0446e-04 - val_loss: 6.3055e-04
#
# Epoch 00073: val_loss did not improve from 0.00059
# Epoch 74/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.0363e-04 - val_loss: 6.1229e-04
#
# Epoch 00074: val_loss did not improve from 0.00059
# Epoch 75/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.0121e-04 - val_loss: 6.0641e-04
#
# Epoch 00075: val_loss did not improve from 0.00059
# Epoch 76/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.0168e-04 - val_loss: 6.1164e-04
#
# Epoch 00076: val_loss did not improve from 0.00059
# Epoch 77/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 9.9780e-05 - val_loss: 6.4009e-04
#
# Epoch 00077: val_loss did not improve from 0.00059
# Epoch 78/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.0300e-04 - val_loss: 6.2754e-04
#
# Epoch 00078: val_loss did not improve from 0.00059
# Epoch 79/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.0158e-04 - val_loss: 6.5163e-04
#
# Epoch 00079: val_loss did not improve from 0.00059
# Epoch 80/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.9607e-05 - val_loss: 6.4547e-04
#
# Epoch 00080: val_loss did not improve from 0.00059
# Epoch 81/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 9.8158e-05 - val_loss: 6.1303e-04
#
# Epoch 00081: val_loss did not improve from 0.00059
# Epoch 82/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 9.7483e-05 - val_loss: 6.1233e-04
#
# Epoch 00082: val_loss did not improve from 0.00059
# Epoch 83/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.8179e-05 - val_loss: 6.0082e-04
#
# Epoch 00083: val_loss did not improve from 0.00059
# Epoch 84/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.0161e-04 - val_loss: 6.1609e-04
#
# Epoch 00084: val_loss did not improve from 0.00059
# Epoch 85/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 9.5931e-05 - val_loss: 6.3247e-04
#
# Epoch 00085: val_loss did not improve from 0.00059
# Epoch 86/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 9.7080e-05 - val_loss: 6.1705e-04
#
# Epoch 00086: val_loss did not improve from 0.00059
# Epoch 87/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 9.6414e-05 - val_loss: 6.1824e-04
#
# Epoch 00087: val_loss did not improve from 0.00059
# Epoch 88/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.4285e-05 - val_loss: 6.3739e-04
#
# Epoch 00088: val_loss did not improve from 0.00059
# Epoch 89/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.3173e-05 - val_loss: 6.0920e-04
#
# Epoch 00089: val_loss did not improve from 0.00059
# Epoch 90/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.3417e-05 - val_loss: 6.2738e-04
#
# Epoch 00090: val_loss did not improve from 0.00059
# Epoch 91/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.1500e-05 - val_loss: 6.2696e-04
#
# Epoch 00091: val_loss did not improve from 0.00059
# Epoch 92/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.0268e-05 - val_loss: 6.1070e-04
#
# Epoch 00092: val_loss did not improve from 0.00059
# Epoch 93/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.9621e-05 - val_loss: 6.1709e-04
#
# Epoch 00093: val_loss did not improve from 0.00059
# Epoch 94/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.1555e-05 - val_loss: 6.4706e-04
#
# Epoch 00094: val_loss did not improve from 0.00059
# Epoch 95/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.8447e-05 - val_loss: 6.2083e-04
#
# Epoch 00095: val_loss did not improve from 0.00059
# Epoch 96/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.8582e-05 - val_loss: 6.3509e-04
#
# Epoch 00096: val_loss did not improve from 0.00059
# Epoch 97/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 9.0613e-05 - val_loss: 6.0808e-04
#
# Epoch 00097: val_loss did not improve from 0.00059
# Epoch 98/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.8901e-05 - val_loss: 6.0679e-04
#
# Epoch 00098: val_loss did not improve from 0.00059
# Epoch 99/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.9255e-05 - val_loss: 6.1550e-04
#
# Epoch 00099: val_loss did not improve from 0.00059
# Epoch 100/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.9143e-05 - val_loss: 6.0899e-04
#
# Epoch 00100: val_loss did not improve from 0.00059
# Epoch 101/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.7968e-05 - val_loss: 6.4130e-04
#
# Epoch 00101: val_loss did not improve from 0.00059
# Epoch 102/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.7054e-05 - val_loss: 6.0924e-04
#
# Epoch 00102: val_loss did not improve from 0.00059
# Epoch 103/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.7033e-05 - val_loss: 6.0015e-04
#
# Epoch 00103: val_loss did not improve from 0.00059
# Epoch 104/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.7834e-05 - val_loss: 6.2947e-04
#
# Epoch 00104: val_loss did not improve from 0.00059
# Epoch 105/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.6576e-05 - val_loss: 6.1804e-04
#
# Epoch 00105: val_loss did not improve from 0.00059
# Epoch 106/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.6300e-05 - val_loss: 6.0189e-04
#
# Epoch 00106: val_loss did not improve from 0.00059
# Epoch 107/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.8289e-05 - val_loss: 6.3834e-04
#
# Epoch 00107: val_loss did not improve from 0.00059
# Epoch 108/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.5343e-05 - val_loss: 6.1159e-04
#
# Epoch 00108: val_loss did not improve from 0.00059
# Epoch 109/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.6018e-05 - val_loss: 6.2950e-04
#
# Epoch 00109: val_loss did not improve from 0.00059
# Epoch 110/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.3132e-05 - val_loss: 6.1043e-04
#
# Epoch 00110: val_loss did not improve from 0.00059
# Epoch 111/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.4550e-05 - val_loss: 6.1728e-04
#
# Epoch 00111: val_loss did not improve from 0.00059
# Epoch 112/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.4163e-05 - val_loss: 6.2493e-04
#
# Epoch 00112: val_loss did not improve from 0.00059
# Epoch 113/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.2673e-05 - val_loss: 6.2215e-04
#
# Epoch 00113: val_loss did not improve from 0.00059
# Epoch 114/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.1255e-05 - val_loss: 6.0427e-04
#
# Epoch 00114: val_loss did not improve from 0.00059
# Epoch 115/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.3013e-05 - val_loss: 6.1516e-04
#
# Epoch 00115: val_loss did not improve from 0.00059
# Epoch 116/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.2934e-05 - val_loss: 6.1051e-04
#
# Epoch 00116: val_loss did not improve from 0.00059
# Epoch 117/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.3287e-05 - val_loss: 6.2067e-04
#
# Epoch 00117: val_loss did not improve from 0.00059
# Epoch 118/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.1845e-05 - val_loss: 6.2206e-04
#
# Epoch 00118: val_loss did not improve from 0.00059
# Epoch 119/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.1182e-05 - val_loss: 6.2133e-04
#
# Epoch 00119: val_loss did not improve from 0.00059
# Epoch 120/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.0714e-05 - val_loss: 6.4043e-04
#
# Epoch 00120: val_loss did not improve from 0.00059
# Epoch 121/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.2015e-05 - val_loss: 6.2331e-04
#
# Epoch 00121: val_loss did not improve from 0.00059
# Epoch 122/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.1512e-05 - val_loss: 6.3562e-04
#
# Epoch 00122: val_loss did not improve from 0.00059
# Epoch 123/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.2009e-05 - val_loss: 6.1025e-04
#
# Epoch 00123: val_loss did not improve from 0.00059
# Epoch 124/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.1663e-05 - val_loss: 6.3326e-04
#
# Epoch 00124: val_loss did not improve from 0.00059
# Epoch 125/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.1441e-05 - val_loss: 6.3834e-04
#
# Epoch 00125: val_loss did not improve from 0.00059
# Epoch 126/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.3043e-05 - val_loss: 6.0716e-04
#
# Epoch 00126: val_loss did not improve from 0.00059
# Epoch 127/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.1806e-05 - val_loss: 6.1152e-04
#
# Epoch 00127: val_loss did not improve from 0.00059
# Epoch 128/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 8.1755e-05 - val_loss: 6.1600e-04
#
# Epoch 00128: val_loss did not improve from 0.00059
# Epoch 129/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.8420e-05 - val_loss: 6.3043e-04
#
# Epoch 00129: val_loss did not improve from 0.00059
# Epoch 130/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.7714e-05 - val_loss: 6.0454e-04
#
# Epoch 00130: val_loss did not improve from 0.00059
# Epoch 131/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.7843e-05 - val_loss: 6.2405e-04
#
# Epoch 00131: val_loss did not improve from 0.00059
# Epoch 132/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 7.7541e-05 - val_loss: 6.2589e-04
#
# Epoch 00132: val_loss did not improve from 0.00059
# Epoch 133/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.9914e-05 - val_loss: 6.0514e-04
#
# Epoch 00133: val_loss did not improve from 0.00059
# Epoch 134/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 7.8274e-05 - val_loss: 6.2993e-04
#
# Epoch 00134: val_loss did not improve from 0.00059
# Epoch 135/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 7.9659e-05 - val_loss: 6.3492e-04
#
# Epoch 00135: val_loss did not improve from 0.00059
# Epoch 136/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 7.7175e-05 - val_loss: 6.3536e-04
#
# Epoch 00136: val_loss did not improve from 0.00059
# Epoch 137/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 7.7201e-05 - val_loss: 6.2248e-04
#
# Epoch 00137: val_loss did not improve from 0.00059
# Epoch 138/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 7.5925e-05 - val_loss: 6.3568e-04
#
# Epoch 00138: val_loss did not improve from 0.00059
# Epoch 139/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 7.7394e-05 - val_loss: 6.1694e-04
#
# Epoch 00139: val_loss did not improve from 0.00059
# Epoch 140/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.6637e-05 - val_loss: 6.1380e-04
#
# Epoch 00140: val_loss did not improve from 0.00059
# Epoch 141/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.4658e-05 - val_loss: 6.4765e-04
#
# Epoch 00141: val_loss did not improve from 0.00059
# Epoch 142/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.7673e-05 - val_loss: 6.2429e-04
#
# Epoch 00142: val_loss did not improve from 0.00059
# Epoch 143/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.7532e-05 - val_loss: 6.3010e-04
#
# Epoch 00143: val_loss did not improve from 0.00059
# Epoch 144/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.7473e-05 - val_loss: 6.3210e-04
#
# Epoch 00144: val_loss did not improve from 0.00059
# Epoch 145/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.4222e-05 - val_loss: 6.3223e-04
#
# Epoch 00145: val_loss did not improve from 0.00059
# Epoch 146/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.5227e-05 - val_loss: 6.2572e-04
#
# Epoch 00146: val_loss did not improve from 0.00059
# Epoch 147/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.6217e-05 - val_loss: 6.2364e-04
#
# Epoch 00147: val_loss did not improve from 0.00059
# Epoch 148/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.8008e-05 - val_loss: 6.3950e-04
#
# Epoch 00148: val_loss did not improve from 0.00059
# Epoch 149/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.4566e-05 - val_loss: 6.3694e-04
#
# Epoch 00149: val_loss did not improve from 0.00059
# Epoch 150/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 7.5056e-05 - val_loss: 6.1317e-04
#
# Epoch 00150: val_loss did not improve from 0.00059

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
